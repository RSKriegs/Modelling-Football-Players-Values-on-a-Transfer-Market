# %%
#single team
import requests
from bs4 import BeautifulSoup
import pandas as pd

teams=pd.read_csv('teams2020.txt', header=None)
teams=pd.Series((teams[0]))
length1=len(teams)

headers = {'User-Agent': 
           'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/47.0.2526.106 Safari/537.36'}

page = "https://www.transfermarkt.de" + teams[0]
pageTree = requests.get(page, headers=headers)
pageSoup = BeautifulSoup(pageTree.content, 'html.parser')


Players = pageSoup.find_all("a", {"class": "spielprofil_tooltip"})[::2]
Values = pageSoup.find_all("td", {"class": "rechts hauptlink"})
PlayersList = []
ValuesList = []
length = len(Values)

for i in range(0,length):
    PlayersList.append(Players[i].text)
    ValuesList.append(Values[i].text)
    
df = pd.DataFrame({"Players":PlayersList,"Values":ValuesList})

df
# Out:
#                 Players           Values
# 0               Ederson   56,00 Mio. €
# 1          Zack Steffen    6,00 Mio. €
# 2          Scott Carson     800 Tsd. €
# 3            Rúben Dias   60,00 Mio. €
# 4       Aymeric Laporte   60,00 Mio. €
# 5            Nathan Aké   40,00 Mio. €
# 6           John Stones   25,00 Mio. €
# 7           Eric García   20,00 Mio. €
# 8      Philippe Sandler    3,50 Mio. €
# 9        Benjamin Mendy   28,00 Mio. €
# 10  Oleksandr Zinchenko   20,00 Mio. €
# 11          Kyle Walker   40,00 Mio. €
# 12         João Cancelo   36,00 Mio. €
# 13                Rodri   64,00 Mio. €
# 14          Fernandinho    4,00 Mio. €
# 15           Phil Foden   60,00 Mio. €
# 16       Ilkay Gündogan   40,00 Mio. €
# 17      Kevin De Bruyne  120,00 Mio. €
# 18      Raheem Sterling  110,00 Mio. €
# 19     Filip Stevanovic    8,00 Mio. €
# 20       Bernardo Silva   70,00 Mio. €
# 21        Ferran Torres   50,00 Mio. €
# 22         Riyad Mahrez   48,00 Mio. €
# ...

# %%
#multiple ones, it works but needs improvement
import requests
from bs4 import BeautifulSoup
import pandas as pd

teams=pd.read_csv('teams2020.txt', header=None)
teams=list((teams[0]))
length1=len(teams)

headers = {'User-Agent': 
           'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/47.0.2526.106 Safari/537.36'}
df=pd.DataFrame()

for i in range(length1):

    page = "https://www.transfermarkt.de" + teams[i]
    pageTree = requests.get(page, headers=headers)
    pageSoup = BeautifulSoup(pageTree.content, 'html.parser')

    Players = pageSoup.find_all("a", {"class": "spielprofil_tooltip"})[::2]
    Values = pageSoup.find_all("td", {"class": "rechts hauptlink"})
    PlayersList = []
    ValuesList = []
     
    length = len(Values)

    for j in range(0,length):
        PlayersList.append(Players[j].text)
        ValuesList.append(Values[j].text)
    
    df1=pd.DataFrame({"Players":PlayersList,"Values":ValuesList})
    df=df.append(df1) 

df.to_csv('bazatest.csv',sep=';')
df
# Out:
#               Players          Values
# 0             Ederson  56,00 Mio. €
# 1        Zack Steffen   6,00 Mio. €
# 2        Scott Carson    800 Tsd. €
# 3          Rúben Dias  60,00 Mio. €
# 4     Aymeric Laporte  60,00 Mio. €
# ..                ...             ...
# 22    Ignatius Ganago   8,00 Mio. €
# 23  Arnaud Kalimuendo   6,00 Mio. €
# 24     Florian Sotoca   1,80 Mio. €
# 25      Corentin Jean   1,60 Mio. €
# 26        Simon Banza   1,50 Mio. €
#
# [2804 rows x 2 columns]

# %%
len(PlayersList)
# Out:
# 46

# %%
#multiple ones, it works but needs improvement
import requests
from bs4 import BeautifulSoup
import pandas as pd

teams=pd.read_csv('teams2020.txt', header=None)
teams=list((teams[0]))
length1=len(teams)

headers = {'User-Agent': 
           'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/47.0.2526.106 Safari/537.36'}
df=pd.DataFrame()

for i in range(length1):

    page = "https://www.transfermarkt.de" + teams[i]
    pageTree = requests.get(page, headers=headers)
    pageSoup = BeautifulSoup(pageTree.content, 'html.parser')

    Players = pageSoup.find_all("span", {"class": "show-for-small"})
    Values = pageSoup.find_all("td", {"class": "rechts hauptlink"})
    PlayersList = [x.text for x in pageSoup.find_all("a", {"class": "spielprofil_tooltip"})][::2]
    ValuesList = []
     
    length = len(Players)

    for i in range(0,length):
        ValuesList.append(Values[i].text)
    
    df1=pd.DataFrame({"Players":PlayersList})
    df2=pd.DataFrame({"Values":ValuesList})
    df=df.append(df1) 

df.to_csv('baza2017.csv',sep=';')
df1
# Out:
#                    Players
# 0          Wuilker Fariñez
# 1          Jean-Louis Leca
# 2           Didier Desprez
# 3           Facundo Medina
# 4                Loïc Badé
# 5          Jonathan Gradit
# 6            Steven Fortes
# 7   Aleksandar Radovanovic
# 8           Zakaria Diallo
# 9            Issiaga Sylla
# 10        Massadio Haidara
# 11            Ismaël Boura
# 12        Clément Michelin
# 13         Jonathan Clauss
# 14           Cheick Traoré
# 15         Cheick Doucouré
# 16         Yannick Cahuzac
# 17             Seko Fofana
# 18             Gaël Kakuta
# 19           Tony Mauricio
# 20             David Costa
# 21            Adam Oudjani
# 22         Ignatius Ganago
# 23       Arnaud Kalimuendo
# 24          Florian Sotoca
# 25           Corentin Jean
# 26             Simon Banza
# 27         Wuilker Fariñez
# 28            Ismaël Boura
# 29         Cheick Doucouré
# 30             Simon Banza
# 31           Corentin Jean

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

teams=pd.read_csv('teams2020.txt', header=None)
teams=list((teams[0]))
length1=len(teams)

headers = {'User-Agent': 
           'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/47.0.2526.106 Safari/537.36'}
df=pd.DataFrame()

for i in range(length1):

    page = "https://www.transfermarkt.de" + teams[i]
    pageTree = requests.get(page, headers=headers)
    pageSoup = BeautifulSoup(pageTree.content, 'html.parser')

    Players = pageSoup.find_all("span", {"class": "show-for-small"})
    Values = pageSoup.find_all("td", {"class": "rechts hauptlink"})
    PlayersList = [x.text for x in pageSoup.find_all("a", {"class": "spielprofil_tooltip"})][::2]
    ValuesList = []
     
    length = len(Players)

    for i in range(0,length):
        ValuesList.append(Values[i].text)
    
    df1=pd.DataFrame({"Players":PlayersList})
    df2=pd.DataFrame({"Values":ValuesList})
    df3=df.append(df1) 
    df4=df.append(df2)

#df.to_csv('baza2020.csv',sep=';')
print(df3,df4)
# Out:
#                    Players
# 0          Wuilker Fariñez
# 1          Jean-Louis Leca
# 2           Didier Desprez
# 3           Facundo Medina
# 4                Loïc Badé
# 5          Jonathan Gradit
# 6            Steven Fortes
# 7   Aleksandar Radovanovic
# 8           Zakaria Diallo
# 9            Issiaga Sylla
# 10        Massadio Haidara
# 11            Ismaël Boura
# 12        Clément Michelin
# 13         Jonathan Clauss
# 14           Cheick Traoré
# 15         Cheick Doucouré
# 16         Yannick Cahuzac
# 17             Seko Fofana
# 18             Gaël Kakuta
# 19           Tony Mauricio
# 20             David Costa
# 21            Adam Oudjani
# 22         Ignatius Ganago
# 23       Arnaud Kalimuendo
# 24          Florian Sotoca
# 25           Corentin Jean
# 26             Simon Banza
# 27         Wuilker Fariñez
# 28            Ismaël Boura
# 29         Cheick Doucouré
# 30             Simon Banza
# 31           Corentin Jean             Values
# 0    3,50 Mio. €
# ...
