# %%
import os
import statistics
import scipy as sp
import import_ipynb
import math
import pandas as pd
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
import matplotlib.ticker as tick
import seaborn as sns
import statsmodels.api as sm
import statsmodels.formula.api as smf
from statsmodels.stats.outliers_influence import variance_inflation_factor
from statsmodels.tools.tools import add_constant
from statsmodels.regression.linear_model import OLS
from statsmodels.stats.outliers_influence import OLSInfluence
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score
from sklearn.base import BaseEstimator, RegressorMixin

# %%
os.chdir('C:\\Users\\rafal\\Desktop\\dane do licencjatu\\code')
import Licencjat_Modelling_Goalkeepers as GK
# Out:
# importing Jupyter notebook from Licencjat_Modelling_Goalkeepers.ipynb
# C:\Users\rafal\anaconda3\lib\site-packages\statsmodels\regression\linear_model.py:1715: RuntimeWarning: divide by zero encountered in double_scalars
#   return 1 - self.ssr/self.centered_tss
# C:\Users\rafal\anaconda3\lib\site-packages\statsmodels\stats\outliers_influence.py:193: RuntimeWarning: divide by zero encountered in double_scalars
#   vif = 1. / (1. - r_squared_i)
# 3.732649079116277 0.9999755428881254 13
# C:\Users\rafal\anaconda3\lib\site-packages\statsmodels\sandbox\regression\gmm.py:290: RuntimeWarning: invalid value encountered in sqrt
#   condno = np.sqrt(eigvals[-1]/eigvals[0])
# C:\Users\rafal\anaconda3\lib\site-packages\statsmodels\regression\linear_model.py:1817: RuntimeWarning: invalid value encountered in sqrt
#   return np.sqrt(np.diag(self.cov_params()))
# 10515104.304464083 10300147.282817144
# [-1.56255297e+14 -1.68889411e+14 -1.04196402e+14 -7.91096423e+13
#  -7.46069964e+13]
# <string>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
os.chdir('C:\\Users\\rafal\\Desktop\\dane do licencjatu\\code')
import Licencjat_Modelling_Defenders as DEF
# Out:
# importing Jupyter notebook from Licencjat_Modelling_Defenders.ipynb
# <string>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# <string>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# <string>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# <string>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\rafal\anaconda3\lib\site-packages\statsmodels\regression\linear_model.py:1715: RuntimeWarning: divide by zero encountered in double_scalars
#   return 1 - self.ssr/self.centered_tss
# C:\Users\rafal\anaconda3\lib\site-packages\statsmodels\stats\outliers_influence.py:193: RuntimeWarning: divide by zero encountered in double_scalars
#   vif = 1. / (1. - r_squared_i)
# -20.360649143298907 0.0 24
# C:\Users\rafal\anaconda3\lib\site-packages\statsmodels\sandbox\regression\gmm.py:290: RuntimeWarning: invalid value encountered in sqrt
#   condno = np.sqrt(eigvals[-1]/eigvals[0])
# C:\Users\rafal\anaconda3\lib\site-packages\statsmodels\regression\linear_model.py:1817: RuntimeWarning: invalid value encountered in sqrt
#   return np.sqrt(np.diag(self.cov_params()))
# 8504345.056436997 8525429.494813336
# [-7.51804939e+13 -8.43733432e+13 -7.48126482e+13 -8.40120537e+13
#  -5.71084008e+13]
# <string>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
os.chdir('C:\\Users\\rafal\\Desktop\\dane do licencjatu\\code')
import Licencjat_Modelling_Midfielders as MID
# Out:
# importing Jupyter notebook from Licencjat_Modelling_Midfielders.ipynb
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  value   R-squared:                       0.497
# Model:                            OLS   Adj. R-squared:                  0.485
# Method:                 Least Squares   F-statistic:                     42.49
# Date:                Tue, 16 Feb 2021   Prob (F-statistic):          3.29e-130
# Time:                        17:02:10   Log-Likelihood:                -17928.
# No. Observations:                1013   AIC:                         3.590e+04
# Df Residuals:                     989   BIC:                         3.602e+04
# Df Model:                          23
# Covariance Type:            nonrobust
# ===============================================================================================
#                                   coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------
# Intercept                   -2.854e+04   1.06e+07     -0.003      0.998   -2.08e+07    2.07e+07
# age                          -9.07e+05   1.05e+05     -8.635      0.000   -1.11e+06   -7.01e+05
# goals                        1.261e+06   2.38e+05      5.293      0.000    7.94e+05    1.73e+06
# assists                      1.609e+05   3.48e+05      0.462      0.644   -5.23e+05    8.45e+05
# height                         1.5e+05   6.89e+04      2.176      0.030    1.48e+04    2.85e+05
# passes_into_final_third      1.247e+05   3.02e+04      4.134      0.000    6.55e+04    1.84e+05
# progressive_passes          -1.563e+05    3.2e+04     -4.889      0.000   -2.19e+05   -9.36e+04
# gca                            3.2e+05   2.12e+05      1.511      0.131   -9.55e+04    7.35e+05
# dribbles_vs:minutes            -4.2155     11.744     -0.359      0.720     -27.262      18.831
# touches_mid_3rd              9998.7455   5828.056      1.716      0.087   -1438.032    2.14e+04
# fouls                       -5.121e+04   4.14e+04     -1.236      0.217   -1.33e+05    3.01e+04
# ball_recoveries               595.1987   1.37e+04      0.044      0.965   -2.63e+04    2.74e+04
# passes_received:minutes        -0.5790      1.244     -0.466      0.642      -3.020       1.862
# passes_blocked:minutes         31.0735     21.705      1.432      0.153     -11.520      73.666
# npxg_xa_per90                4.973e+05   4.34e+06      0.115      0.909   -8.01e+06    9.01e+06
# passes_into_penalty_area     3.701e+05   7.68e+04      4.821      0.000    2.19e+05    5.21e+05
# crosses_into_penalty_area   -4.811e+05   1.46e+05     -3.285      0.001   -7.68e+05   -1.94e+05
# corner_kicks_in             -1.194e+05   4.75e+04     -2.516      0.012   -2.13e+05   -2.63e+04
# passes_received_pct:minutes  -105.3175     24.062     -4.377      0.000    -152.535     -58.100
# passes_completed             1.761e+04   3760.200      4.682      0.000    1.02e+04     2.5e+04
# isPremierLeague              2.025e+06   2.23e+06      0.909      0.364   -2.35e+06     6.4e+06
# isLaLiga                     1.492e+05    2.2e+06      0.068      0.946   -4.17e+06    4.47e+06
# isSerieA                     -5.98e+05   2.35e+06     -0.255      0.799    -5.2e+06    4.01e+06
# isBundesliga                   1.8e+05   2.32e+06      0.078      0.938   -4.37e+06    4.73e+06
# isLigue1                    -1.785e+06   2.24e+06     -0.798      0.425   -6.17e+06     2.6e+06
# ==============================================================================
# Omnibus:                      601.908   Durbin-Watson:                   1.686
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             7963.310
# Skew:                           2.480   Prob(JB):                         0.00
# Kurtosis:                      15.809   Cond. No.                     6.98e+21
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 9.26e-29. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# C:\Users\rafal\anaconda3\lib\site-packages\statsmodels\regression\linear_model.py:1715: RuntimeWarning: divide by zero encountered in double_scalars
#   return 1 - self.ssr/self.centered_tss
# C:\Users\rafal\anaconda3\lib\site-packages\statsmodels\stats\outliers_influence.py:193: RuntimeWarning: divide by zero encountered in double_scalars
#   vif = 1. / (1. - r_squared_i)
# -8.637151245245722 0.0 24
# C:\Users\rafal\anaconda3\lib\site-packages\statsmodels\base\model.py:1832: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 24, but rank is 22
#   warnings.warn('covariance of constraints does not have full '
# C:\Users\rafal\anaconda3\lib\site-packages\statsmodels\regression\linear_model.py:1817: RuntimeWarning: invalid value encountered in sqrt
#   return np.sqrt(np.diag(self.cov_params()))
# 11483768.548652567 11637397.130154172
# [-1.19362024e+14 -1.28851419e+14 -1.64243468e+14 -1.51539652e+14
#  -1.35976610e+14]
# <string>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
os.chdir('C:\\Users\\rafal\\Desktop\\dane do licencjatu\\code')
import Licencjat_Modelling_Forwards as FWD
# Out:
# importing Jupyter notebook from Licencjat_Modelling_Forwards.ipynb
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  value   R-squared:                       0.608
# Model:                            OLS   Adj. R-squared:                  0.598
# Method:                 Least Squares   F-statistic:                     58.57
# Date:                Tue, 16 Feb 2021   Prob (F-statistic):          1.27e-165
# Time:                        17:02:15   Log-Likelihood:                -16688.
# No. Observations:                 930   AIC:                         3.343e+04
# Df Residuals:                     905   BIC:                         3.355e+04
# Df Model:                          24
# Covariance Type:            nonrobust
# =====================================================================================================
#                                         coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------------
# Intercept                          4.379e+05   6.33e+06      0.069      0.945    -1.2e+07    1.29e+07
# age                               -8.572e+05    1.4e+05     -6.142      0.000   -1.13e+06   -5.83e+05
# goals                              1.391e+06   2.24e+05      6.222      0.000    9.52e+05    1.83e+06
# assists                            5.558e+05   2.95e+05      1.885      0.060   -2.29e+04    1.13e+06
# shots_total:minutes                 -19.7954     19.975     -0.991      0.322     -58.998      19.407
# passes_pct:minutes                  -97.6651     29.375     -3.325      0.001    -155.317     -40.013
# crosses_into_penalty_area:minutes  -339.7824     95.630     -3.553      0.000    -527.465    -152.099
# sca_per90                          2.306e+05   5.95e+05      0.388      0.698   -9.37e+05     1.4e+06
# errors:minutes                    -1134.1491   1012.570     -1.120      0.263   -3121.408     853.110
# pass_targets:minutes                 -7.0498      2.093     -3.369      0.001     -11.157      -2.943
# xg_per90                           5.061e+05   4.11e+06      0.123      0.902   -7.56e+06    8.58e+06
# passes_pct                          3.61e+05   9.71e+04      3.719      0.000    1.71e+05    5.51e+05
# dribbles_vs:minutes                 -82.9330     21.614     -3.837      0.000    -125.352     -40.514
# touches_att_pen_area:minutes         72.1639     12.158      5.935      0.000      48.302      96.026
# passes_into_final_third:minutes      37.5105     24.207      1.550      0.122      -9.998      85.019
# passes_ground:minutes                17.4899      3.072      5.694      0.000      11.461      23.519
# gca_dribbles:minutes               -369.4883    250.983     -1.472      0.141    -862.064     123.088
# crosses                            1.787e+05   4.89e+04      3.657      0.000    8.28e+04    2.75e+05
# isLaLiga                           5.167e+05   1.62e+06      0.320      0.749   -2.66e+06    3.69e+06
# isPremierLeague                    2.952e+06   1.63e+06      1.814      0.070   -2.42e+05    6.15e+06
# isBundesliga                      -6.113e+05   1.58e+06     -0.387      0.699   -3.71e+06    2.49e+06
# isSerieA                           -7.97e+05    1.8e+06     -0.442      0.658   -4.33e+06    2.74e+06
# isLigue1                          -1.622e+06   1.61e+06     -1.006      0.315   -4.79e+06    1.54e+06
# CL                                 4.611e+06   1.51e+06      3.062      0.002    1.66e+06    7.57e+06
# WinCL                              6.176e+05   4.76e+06      0.130      0.897   -8.73e+06    9.96e+06
# CLBestScorer                       8.427e+04   1.17e+07      0.007      0.994   -2.29e+07     2.3e+07
# ==============================================================================
# Omnibus:                      645.113   Durbin-Watson:                   1.466
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            14514.679
# Skew:                           2.847   Prob(JB):                         0.00
# Kurtosis:                      21.497   Cond. No.                     2.47e+15
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 8.71e-16. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# C:\Users\rafal\anaconda3\lib\site-packages\statsmodels\regression\linear_model.py:1715: RuntimeWarning: divide by zero encountered in double_scalars
#   return 1 - self.ssr/self.centered_tss
# C:\Users\rafal\anaconda3\lib\site-packages\statsmodels\stats\outliers_influence.py:193: RuntimeWarning: divide by zero encountered in double_scalars
#   vif = 1. / (1. - r_squared_i)
# -15.511906191012033 0.0 25
# nan nan
# [-1.57766494e+14 -2.48390477e+14 -2.10195739e+14 -1.92176433e+14
#  -2.79575995e+14]
# <string>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
#correlations
correlations=pd.concat([GK.show,DEF.show,MID.show,FWD.show],axis=1)
#further editions in Excel
#!pip install openpyxl
correlations.columns=['Goalkeepers','Defenders','Midfielders','Forwards']
correlations.to_excel(r'C:\Users\rafal\Desktop\dane do licencjatu\data\correlations.xlsx')
os.system('start EXCEL.EXE correlations.xlsx')
# Out:
# 0
